# %% [markdown]
# ## Hammad Mubarik

# %% [markdown]
# # Problem 1

# %% [markdown]
# ## Part 1 Parity function

# %% [markdown]
# ## Add import

# %%
import numpy as np

# %%
def Parity(x, y, z):
    """XOR three 32-bit words"""
    x = np.uint32(x)
    y = np.uint32(y)
    z = np.uint32(z)
    return np.uint32(x ^ y ^ z)
